# %% [markdown]
# # APIs
#
# Instead of downloading World Bank data via a csv file, you're going to download the data using the World Bank APIs. The purpose of this exercise is to gain experience with another way of extracting data.
#
# API is an acronym that stands for application programming interface. API’s provide a standardized way for two applications to talk to each other. In this case, the applications communicating with each other are the server application where World Bank stores data and your Jupyter notebook.
#
# If you wanted to pull data directly from the World Bank’s server, you’d have to know what database system the World Bank was using. You’d also need permission to log in directly to the server, which would be a security risk for the World Bank. And if the World Bank ever migrated its data to a new system, you would have to rewrite all of your code again. The API allows you to execute code on the World Bank server without getting direct access.
#
# # Before there were APIs
#
# Before there were APIs, there was web scraping. People would download html directly from a website and then parse the results programatically. This practice is in a legal grey area. One reason that APIs became popular was so that companies could provide data to users and discourage web scraping.
#
# Here are a few articles about the legality of web scraping.
#
# * [QVC Can't Stop Web Scraping](https://www.forbes.com/sites/ericgoldman/2015/03/24/qvc-cant-stop-web-scraping/#120db59b3ca3)
# * [Quora - Legality of Web Scraping](https://www.quora.com/What-is-the-legality-of-web-scraping)
#
# All sorts of companies have public facing APIs including Facebook, Twitter, Google and Pinterest. You can pull data from these companies to create your own applications.
#
# In this notebook, you’ll get practice using Python to pull data from the World Bank indicators API.
#
# Here are links to information about the World Bank indicators and projects APIs if you want to learn more:
# * [World Bank Indicators API](world bank projects api)
# * [World Bank Projects API](http://search.worldbank.org/api/v2/projects)

# %% [markdown]
# # Using APIs
#
# In general, you access APIs via the web using a web address. Within the web address, you specify the data that you want. To know how to format the web address, you need to read an API's documentation. Some APIs also require that you send login credentials as part of your request. The World Bank APIs are public and do not require login credentials.
#
# The Python requests library makes working with APIs relatively simple.

# %% [markdown]
# # Example Indicators API
#
# Run the code example below to request data from the World Bank Indicators API. According to the documntation, you format your request url like so:
#
# `http://api.worldbank.org/v2/countries/` + list of country abbreviations separated by ; + `/indicators/` + indicator name + `?` + options
#
# where options can include
# * per_page - number of records to return per page
# * page - which page to return - eg if there are 5000 records and 100 records per page
# * date - filter by dates
# * format - json or xml
#
#  and a few other options that you can read about [here](https://datahelpdesk.worldbank.org/knowledgebase/articles/898581-api-basic-call-structure).

# %%
#   http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json
    
#   http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?date=2000

# %%
url = 'http://api.worldbank.org/v2/country/chn;bra/indicator/DPANUSSPB?format=json&date=2012M01'
a = requests.get(url)
a.json()
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 2,
#   'sourceid': '15',
#   'sourcename': '',
#   'lastupdated': '2020-07-27'},
#  [{'indicator': {'id': 'DPANUSSPB',
#     'value': 'Exchange rate, new LCU per USD extended backward, period average,,'},
#    'country': {'id': 'BRA', 'value': 'Brazil'},
#    'countryiso3code': '',
#    'date': '2012M01',
#    'value': 1.78886363636,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'DPANUSSPB',
#     'value': 'Exchange rate, new LCU per USD extended backward, period average,,'},
#    'country': {'id': 'CHN', 'value': 'China'},
#    'countryiso3code': '',
#    'date': '2012M01',
#    'value': 6.31309090909,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
url = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&date=2000:2001'
b = requests.get(url)
b.json()
# Out:
# [{'page': 1,
#   'pages': 11,
#   'per_page': 50,
#   'total': 528,
#   'sourceid': '2',
#   'sourcename': 'World Development Indicators',
#   'lastupdated': '2021-04-26'},
#  [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2001',
#    'value': 288432163,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2000',
#    'value': 282344154,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2001',
#    'value': 6559094,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2000',
#    'value': 6513489,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2001',
#    'value': 107660041,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2000',
#    'value': 108447824,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2001',
#    'value': 2516662229,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2000',
#    'value': 2472852823,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2001',
#    'value': 2065912076,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2000',
#    'value': 2047640119,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2001',
#    'value': 1833423014,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2000',
#    'value': 1816455805,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'countryiso3code': 'TEA',
#    'date': '2001',
#    'value': 1810261141,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'countryiso3code': 'TEA',
#    'date': '2000',
#    'value': 1793498351,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2001',
#    'value': 322547874,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2000',
#    'value': 321310791,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2001',
#    'value': 862347940,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2000',
#    'value': 861278548,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2001',
#    'value': 369183312,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2000',
#    'value': 369143668,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T7',
#     'value': 'Europe & Central Asia (IDA & IBRD countries)'},
#    'countryiso3code': 'TEC',
#    'date': '2001',
#    'value': 433863000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T7',
#     'value': 'Europe & Central Asia (IDA & IBRD countries)'},
#    'countryiso3code': 'TEC',
#    'date': '2000',
#    'value': 434313570,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2001',
#    'value': 429895628,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2000',
#    'value': 429328624,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2001',
#    'value': 517162716,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2000',
#    'value': 504450718,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2001',
#    'value': 485112686,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2000',
#    'value': 471680794,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2001',
#    'value': 1108227432,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2000',
#    'value': 1101479766,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2001',
#    'value': 4032822501,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2000',
#    'value': 3987195310,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2001',
#    'value': 5137401873,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2000',
#    'value': 5065364314,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2001',
#    'value': 368820681,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2000',
#    'value': 360173360,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2001',
#    'value': 735758691,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2000',
#    'value': 717995644,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2001',
#    'value': 1104579372,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2000',
#    'value': 1078169004,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2001',
#    'value': 2059873500,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2000',
#    'value': 2045125923,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2001',
#    'value': 528283160,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2000',
#    'value': 520903450,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2001',
#    'value': 500087458,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2000',
#    'value': 492968023,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T2',
#     'value': 'Latin America & the Caribbean (IDA & IBRD countries)'},
#    'countryiso3code': 'TLA',
#    'date': '2001',
#    'value': 512247471,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T2',
#     'value': 'Latin America & the Caribbean (IDA & IBRD countries)'},
#    'countryiso3code': 'TLA',
#    'date': '2000',
#    'value': 504921262,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2001',
#    'value': 673903112,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2000',
#    'value': 657215864,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
url = 'http://api.worldbank.org/v2/country/chn;bra/indicator/DPANUSSPB?format=json&date=2012M01:2012M080'
c = requests.get(url)
c.json()
# Out:
# [{'message': [{'id': '120',
#     'key': 'Invalid value',
#     'value': 'The provided parameter value is not valid'}]}]

# %%
url='http://api.worldbank.org/v2/country/CHL/indicator/DP.DOD.DECD.CR.BC.CD?format=json&date=2013Q1:2013Q4'
d=requests.get(url)
d.json()
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 4,
#   'sourceid': '20',
#   'sourcename': 'Quarterly Public Sector Debt',
#   'lastupdated': '2021-04-28'},
#  [{'indicator': {'id': 'DP.DOD.DECD.CR.BC.CD',
#     'value': 'Gross PSD, Budgetary Central Gov., All maturities, All instruments, Domestic creditors, Nominal Value, US$'},
#    'country': {'id': 'CL', 'value': 'Chile'},
#    'countryiso3code': 'CHL',
#    'date': '2013Q4',
#    'value': 32657705593.7269,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'DP.DOD.DECD.CR.BC.CD',
#     'value': 'Gross PSD, Budgetary Central Gov., All maturities, All instruments, Domestic creditors, Nominal Value, US$'},
#    'country': {'id': 'CL', 'value': 'Chile'},
#    'countryiso3code': 'CHL',
#    'date': '2013Q3',
#    'value': 33080148230.298,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'DP.DOD.DECD.CR.BC.CD',
#     'value': 'Gross PSD, Budgetary Central Gov., All maturities, All instruments, Domestic creditors, Nominal Value, US$'},
#    'country': {'id': 'CL', 'value': 'Chile'},
#    'countryiso3code': 'CHL',
#    'date': '2013Q2',
#    'value': 31039814868.6004,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'DP.DOD.DECD.CR.BC.CD',
#     'value': 'Gross PSD, Budgetary Central Gov., All maturities, All instruments, Domestic creditors, Nominal Value, US$'},
#    'country': {'id': 'CL', 'value': 'Chile'},
#    'countryiso3code': 'CHL',
#    'date': '2013Q1',
#    'value': 31049138725.7794,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
import requests
import pandas as pd

url = 'http://api.worldbank.org/v2/countries/br;cn;us;de/indicators/SP.POP.TOTL/?format=json&per_page=50'
r = requests.get(url)
r.json()
pd.DataFrame(r.json()[1]).head()
# Out:
#                                            indicator  \
# 0  {'id': 'SP.POP.TOTL', 'value': 'Population, to...
# 1  {'id': 'SP.POP.TOTL', 'value': 'Population, to...
# 2  {'id': 'SP.POP.TOTL', 'value': 'Population, to...
# 3  {'id': 'SP.POP.TOTL', 'value': 'Population, to...
# 4  {'id': 'SP.POP.TOTL', 'value': 'Population, to...
#
#                            country countryiso3code  date        value unit  \
# 0  {'id': 'BR', 'value': 'Brazil'}             BRA  2020          NaN
# 1  {'id': 'BR', 'value': 'Brazil'}             BRA  2019  211049527.0
# 2  {'id': 'BR', 'value': 'Brazil'}             BRA  2018  209469333.0
# 3  {'id': 'BR', 'value': 'Brazil'}             BRA  2017  207833831.0
# 4  {'id': 'BR', 'value': 'Brazil'}             BRA  2016  206163058.0
#
#   obs_status  decimal
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# This json data isn't quite ready for a pandas data frame. Notice that the json response is a list with two entries. The first entry is
# ```
# {'lastupdated': '2018-06-28',
#   'page': 1,
#   'pages': 1,
#   'per_page': 1000,
#   'total': 232}
# ```
#
# That first entry is meta data about the results. For example, it says that there is one page returned with 232 results.
#
# The second entry is another list containing the data. This data would need some cleaning to be used in a pandas data frame. That would happen later in the transformation step of an ETL pipeline. Run the cell below to read the results into a dataframe and see what happens.

# %%
###
# Run this cell that converts the json into a dataframe
# Note that you do not need the pd.read_json() method because this is not a file or a string containing json 
##

pd.DataFrame(r.json()[1])

# %% [markdown]
# There are some issues with this dataframe. The country and indicator variables don't look particularly useful in their current form. Again, dealing with those issues would come in the transformation phase of a pipeline, which comes later in the lesson.

# %% [markdown]
# # Exercise Indicators API
#
# Use the Indicators API to request rural population data for Switzerland in the years 1995 through 2001. Here are a few helpful resources:
# * [documentation included how to filter by year](https://datahelpdesk.worldbank.org/knowledgebase/articles/898581-api-basic-call-structure)
# * [2-character iso country codes](https://www.nationsonline.org/oneworld/country_code_list.htm)
# * [search box for World Bank indicators](https://data.worldbank.org)
#
# To find the indicator code, first search for the indicator here: https://data.worldbank.org
# Click on the indicator name. The indicator code is in the url. For example, the indicator code for total population is SP.POP.TOTL, which you can see in the link [https://data.worldbank.org/indicator/SP.RUR.TOTL](https://data.worldbank.org/indicator/SP.RUR.TOTL).

# %%
# TODO: get the url ready

# %%
url='http://api.worldbank.org/v2/countries/ch/indicators/SP.RUR.TOTL?format=json&date=1995:2001'
s=requests.get(url)
s.json()
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 7,
#   'sourceid': '2',
#   'sourcename': 'World Development Indicators',
#   'lastupdated': '2021-04-26'},
#  [{'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '2001',
#    'value': 1924949,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '2000',
#    'value': 1912232,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '1999',
#    'value': 1897587,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '1998',
#    'value': 1884719,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '1997',
#    'value': 1875299,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '1996',
#    'value': 1866968,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL', 'value': 'Rural population'},
#    'country': {'id': 'CH', 'value': 'Switzerland'},
#    'countryiso3code': 'CHE',
#    'date': '1995',
#    'value': 1854939,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]
